# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
import plotly.express as px

# %%
#Relational plot
tip=sns.load_dataset('tips')
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
gap=px.data.gapminder()

# %%
gap
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
sns.scatterplot(data=tip,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(data=tip,x='total_bill',y='tip',kind='scatter')

# %%
#facet plot
sns.relplot(data=tip,x='total_bill',y='tip',kind='scatter',col='sex',row='smoker')

# %%
sns.relplot(data=gap,x='lifeExp',y='gdpPercap',kind='scatter',col='year',col_wrap=4)

# %%
#distribution plot
#Histgram
sns.histplot(data=tip,x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.displot(data=tip,x='total_bill',kind='hist')

# %%
sns.displot(data=tip,x='total_bill',kind='hist',bins=20)

# %%
sns.displot(data=tip,x='day',kind='hist',bins=20)

# %%
titanic = sns.load_dataset('titanic')

# %%
sns.displot(data=titanic,x='age',kind='hist',element ='step',hue='sex')

# %%
#kdeplot

# %%
sns.kdeplot(data=tip,x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.displot(data=tip,x='total_bill',kind='kde')

# %%
sns.displot(data=tip,x='total_bill',kind='kde',hue='sex',fill=True)

# %%
sns.kdeplot(data=tip,x='total_bill')
sns.rugplot(data=tip,x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.histplot(data=tip,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.kdeplot(data=tip,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
#heap
a=gap.pivot(index='country',columns='year',values='lifeExp')

# %%
sns.heatmap(data=a)
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %%
b= gap[gap['continent']=='Europe'].pivot(index='country',columns='year',values='lifeExp')

# %%
sns.heatmap(data=b,annot=True)
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %%
iris=px.data.iris()

# %%
sns.clustermap(iris.iloc[:,[0,1,2,3]])

# %%
sns.stripplot(data=tip,x='day',y='total_bill',jitter=False)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(data=tip,x='day',y='total_bill',kind='strip')

# %%
sns.catplot(data=tip,x='day',y='total_bill',kind='strip',jitter=0.1)

# %%
sns.catplot(data=tip,x='day',y='total_bill',kind='swarm',hue='sex')

# %%
#boxplot
sns.boxplot(data=tip,x='sex',y='total_bill')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
#violoinplot
sns.violinplot(data=tip,x='day',y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(data=tip,x='day',y='total_bill',kind='violin',hue='sex')

# %%
sns.catplot(data=tip,x='day',y='total_bill',kind='violin',hue='sex',split=True)

# %%
import numpy as np

# %%
sns.barplot(data=tip,x='day',y='total_bill',hue='smoker',estimator=np.min)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.pointplot(data=tip,x='day',y='total_bill',hue='smoker',estimator=np.min)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(data=tip,x='day',y='total_bill',hue='smoker',estimator='mean',errorbar=('ci',2))
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.countplot(data=tip,x='sex',hue='day')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
#faceting
sns.catplot(data=tip,x='sex',y='total_bill',col='smoker',kind='box',row='time')

# %%
#reg plot
sns.regplot(data=tip,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lmplot(data=tip,x='total_bill',y='tip',hue='sex')

# %%
sns.catplot(data=tip,x='sex',y='total_bill',kind='violin',col='day',row='time')

# %%
g=sns.FacetGrid(data=tip,col='day',row='time')
g.map(sns.violinplot,'sex','total_bill')
# Out:
# C:\Users\Hp\anaconda3\Lib\site-packages\seaborn\axisgrid.py:712: UserWarning: Using the violinplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
g=sns.FacetGrid(data=tip,col='day',row='time',hue='smoker')
g.map(sns.violinplot,'sex','total_bill')
g.add_legend()
# Out:
# C:\Users\Hp\anaconda3\Lib\site-packages\seaborn\axisgrid.py:712: UserWarning: Using the violinplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      species_id
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# ...

# %%
 sns.pairplot(iris,hue='species')

# %%
g  = sns.PairGrid(data=iris)
g.map(sns.scatterplot)

# %%
g  = sns.PairGrid(data=iris)
g.map_diag(sns.violinplot)
g.map_offdiag(sns.kdeplot)

# %%
g = sns.PairGrid(data=iris,hue='species')
g.map_diag(sns.violinplot)
g.map_upper(sns.kdeplot)
g.map_lower(sns.scatterplot)
# Out:
# C:\Users\Hp\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1609: UserWarning: KDE cannot be estimated (0 variance or perfect covariance). Pass `warn_singular=False` to disable this warning.
#   func(x=x, y=y, **kwargs)
# C:\Users\Hp\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1609: UserWarning: KDE cannot be estimated (0 variance or perfect covariance). Pass `warn_singular=False` to disable this warning.
#   func(x=x, y=y, **kwargs)
# C:\Users\Hp\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1609: UserWarning: KDE cannot be estimated (0 variance or perfect covariance). Pass `warn_singular=False` to disable this warning.
#   func(x=x, y=y, **kwargs)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[95], line 3
#       1 g = sns.PairGrid(data=iris,hue='species')
#       2 g.map_diag(sns.violinplot)
# ----> 3 g.map_upper(sns.kdeplot)
# ...

# %%
sns.jointplot(data=tip,x='total_bill',y='tip',hue='sex')

# %%
g=sns.JointGrid(data=tip,x='total_bill',y='tip')
g.plot(sns.scatterplot,sns.histplot)
